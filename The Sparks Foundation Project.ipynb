# %% [markdown]
# # Problem Statement

# %% [markdown]
# Exploratory Data Analysis- Retail
#
#
# In this task we have to perform EDA on Sample_Super_Store Dataset. As a business manager, try to find out the weak areas where you can work to make more profit.

# %% [markdown]
# # Author: VICKY
# Task-3 Exploratory Data Analysis : Sample Super Store Dataset

# %% [markdown]
# # Importing Libraries

# %%
# pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train=pd.read_csv('SampleSuperstore.csv')
train.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State
# 0    Second Class   Consumer  United States        Henderson    Kentucky  \
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity
# 0        42420  South        Furniture    Bookcases  261.9600         2  \
# ...

# %% [markdown]
# Importing dataset with the help of pd.read_csv method.

# %%
df=train

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# we have 9994 row and 13 columns

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# The total features names are mentioned above.

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# Here we are checking which types of we have, According to above the maximum columns we have are categorical and Numerical are less.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# The df.info() method provide us full details about our dataset i.e., datatype, total number of columns, total number of row.

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# Statistical Summary provide information about whole data statistically i.e. Count, Mean, Standard Deviation, Minimum value, 25%, 50% 75% and Maximum Value and statistical report is mentioned above.

# %% [markdown]
# # Before Graphically Visualization here we are trying to check unique items of each features. It will help us for better visualization.

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['Quantity'].unique()
# Out:
# array([ 2,  3,  5,  7,  4,  6,  9,  1,  8, 14, 11, 13, 10, 12],
#       dtype=int64)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # Here we are counting the each features total unique entries

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df['Country'].value_counts()
# Out:
# Country
# United States    9994
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df['Sales'].value_counts()
# Out:
# Sales
# 12.960     56
# 19.440     39
# 15.552     39
# 25.920     36
# 10.368     36
#            ..
# 4.240       1
# 319.960     1
# 646.740     1
# 81.940      1
# 243.160     1
# Name: count, Length: 5825, dtype: int64

# %%
df['Quantity'].value_counts()
# Out:
# Quantity
# 3     2409
# 2     2402
# 5     1230
# 4     1191
# 1      899
# 7      606
# 6      572
# 9      258
# 8      257
# 10      57
# 11      34
# 14      29
# 13      27
# 12      23
# Name: count, dtype: int64

# %% [markdown]
# # Univariate, and Bivariate analysis

# %% [markdown]
# # Visualization by Countplot, and Piechart

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="Ship Mode")
plt.xticks(rotation=90)
plt.title("Ship Mode", fontsize = 5)
# Out:
# Text(0.5, 1.0, 'Ship Mode')

# %% [markdown]
# According to Ship Mode the Standard Class in highest. The maximum product shiped by Standard Class.

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="Segment")
plt.xticks(rotation=360)
plt.title("Segment", fontsize = 10)
# Out:
# Text(0.5, 1.0, 'Segment')

# %% [markdown]
# Consumer products are the highest count. Corporate and Home office are lesser than Consumer.

# %%
df_categ = df.groupby(['Segment']).sum()[['Profit','Sales']]
df_categ[['Sales','Profit']].plot.pie(subplots=True, figsize=(20,10),autopct='%1.1f%%');

# %% [markdown]
# If we compare segment by sales and profit. The Consumer sales and profit are the highest from others.
#
# Consumer Sales = 50.6%
#
# Consumer Profit = 46.8%

# %%
data_segment = df.groupby(['Segment'])[['Sales','Profit']].mean()
data_segment
# Out:
#                   Sales     Profit
# Segment
# Consumer     223.733644  25.836873
# Corporate    233.823300  30.456667
# Home Office  240.972041  33.818664

# %% [markdown]
# Average Sales and Profit of each Segment.

# %%
data_segment.sum(axis=0)
# Out:
# Sales     698.528985
# Profit     90.112204
# dtype: float64

# %%
data_segment['Sales%'] = data_segment['Sales']/6.985
data_segment['Profit%'] = data_segment['Profit']/9.011

# %%
data_segment.sort_values('Profit')
# Out:
#                   Sales     Profit     Sales%   Profit%
# Segment
# Consumer     223.733644  25.836873  32.030586  2.867259
# Corporate    233.823300  30.456667  33.475061  3.379943
# Home Office  240.972041  33.818664  34.498503  3.753042

# %% [markdown]
# Segments Total Average Sales, Total Average Profit with Sales and Profit percentage are given here.

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="State")
plt.xticks(rotation=90)
plt.title("State", fontsize = 10)
# Out:
# Text(0.5, 1.0, 'State')

# %% [markdown]
# According to State wise analysie the California is the only state which are highest counts and Second highest counts are New York and Wyoming is lowest one

# %%
data_state = df.groupby(['State'])[['Sales','Profit']].mean()

# %%
data_state.sum(axis=0)
# Out:
# Sales     13545.408037
# Profit     2648.344280
# dtype: float64

# %%
data_state['Sales%'] = data_state['Sales']/1.354
data_state['Profit%'] = data_state['Profit']/2.648

# %%
data_state.sort_values('Profit')
# Out:
#                             Sales      Profit       Sales%    Profit%
# State
# Ohio                   166.861697  -36.186304   123.236113 -13.665523
# Colorado               176.418231  -35.867351   130.294114 -13.545072
# North Carolina         223.305880  -30.083985   164.923102 -11.361021
# Tennessee              167.551219  -29.189583   123.745361 -11.023256
# Pennsylvania           198.487077  -26.507598   146.593114 -10.010422
# Texas                  172.779742  -26.121174   127.606900  -9.864492
# Illinois               162.939230  -25.625787   120.339165  -9.677412
# Arizona                157.508933  -15.303235   116.328606  -5.779167
# Oregon                 140.573790   -9.600569   103.821115  -3.625592
# Florida                233.612815   -8.875461   172.535314  -3.351760
# New Mexico             129.284378   31.273408    95.483293  11.810199
# North Dakota           131.415714   32.878529    97.057396  12.416363
# ...

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="Region")
plt.xticks(rotation=90)
plt.title("Region", fontsize = 5)
# Out:
# Text(0.5, 1.0, 'Region')

# %% [markdown]
# Maximum Super Store are in West Region as we are getting from above mentioned graph.

# %%
df_reg = df.groupby(['Region']).sum()[['Profit','Sales']]
df_reg[['Sales','Profit']].plot.pie(subplots=True, figsize=(20,10),autopct='%1.1f%%');

# %% [markdown]
# Region wiese Sales and profit.
#
# As we know Western region have highest sales and also have highest profit.
#
# Second Highest region is Eastern and also have second higest profit.
#
# Southern have lowest sales and lowest profit.

# %%
data_region = df.groupby(['Region'])[['Sales','Profit']].mean()

# %%
data_region.sum(axis=0)
# Out:
# Sales     922.405648
# Profit    111.935221
# dtype: float64

# %%
data_region['Sales%'] = data_region['Sales']/9.224
data_region['Profit%'] = data_region['Profit']/1.119

# %%
data_region.sort_values('Profit')
# Out:
#               Sales     Profit     Sales%    Profit%
# Region
# Central  215.772661  17.092709  23.392526  15.274986
# South    241.803645  28.857673  26.214619  25.788805
# East     238.336110  32.135808  25.838694  28.718327
# West     226.493233  33.849032  24.554774  30.249358

# %% [markdown]
# Region wise Total Average Sales, Total Average Profit with Sales% and Profit%

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="Category")
plt.xticks(rotation=360)
plt.title("Category", fontsize = 5)
# Out:
# Text(0.5, 1.0, 'Category')

# %% [markdown]
# If we analysie by category wise the Office Supplies is the highest one, furniture and technology lower than office supplies

# %%
df_categ = df.groupby(['Category']).sum()[['Profit','Sales']]
df_categ[['Sales','Profit']].plot.pie(subplots=True, figsize=(20,10),autopct='%1.1f%%');

# %% [markdown]
# Category wise Sales and profit.
#
#
# As we know Technology have highest sales and also have highest profit.
#
# Sales = 36.4%
# Profit = 50.8%
#
# If we talk about office supplies. Its sales are high and profit are also accordingly.
#
# Sales = 31.3%
# Profit = 42.8%
#
# In case of Furniture the sales of furniture are good (32.3%) but profit are not accordingly.

# %%
data_category = df.groupby(['Category'])[['Sales','Profit']].mean()

# %%
data_category.sum(axis=0)
# Out:
# Sales     921.868264
# Profit    107.778379
# dtype: float64

# %%
data_category['Sales%'] = data_category['Sales']/9.224
data_category['Profit%'] = data_category['Profit']/1.119

# %%
data_category.sort_values('Profit')
# Out:
#                       Sales     Profit     Sales%    Profit%
# Category
# Furniture        349.834887   8.699327  37.926592   7.774198
# Office Supplies  119.324101  20.327050  12.936264  18.165370
# Technology       452.709276  78.752002  49.079497  70.377124

# %% [markdown]
# Category wise Total Average Sales, Profit and Sales% and Profit%

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="Sub-Category")
plt.xticks(rotation=90)
plt.title("Sub-Category", fontsize = 5)
# Out:
# Text(0.5, 1.0, 'Sub-Category')

# %% [markdown]
# According to Sub-Category the Binders are highest and Copiers are Lowest

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(18,14))
sns.barplot(x='Sub-Category',y='Profit', data=df, palette='Spectral')
plt.suptitle('Sub-Category', fontsize=16)
plt.show()

# %% [markdown]
# If we analysie profit graphically the Profit of Copiers are very high but there are few items they are in loss i.e., Bookcases, Tables and Machines.

# %%
data_Subcategory = df.groupby(['Sub-Category'])[['Sales','Profit']].mean()
data_Subcategory
# Out:
#                     Sales      Profit
# Sub-Category
# Accessories    215.974604   54.111788
# Appliances     230.755710   38.922758
# Art             34.068834    8.200737
# Binders        133.560560   19.843574
# Bookcases      503.859633  -15.230509
# Chairs         532.332420   43.095894
# Copiers       2198.941618  817.909190
# Envelopes       64.867724   27.418019
# Fasteners       13.936774    4.375660
# Furnishings     95.825668   13.645918
# Labels          34.303055   15.236962
# Machines      1645.553313   29.432669
# Paper           57.284092   24.856620
# Phones         371.211534   50.073938
# Storage        264.590553   25.152277
# Supplies       245.650200   -6.258418
# Tables         648.794771  -55.565771

# %% [markdown]
# Total sales and Total Profit of Sub-Category items.

# %%
data_Subcategory.sum(axis=0)
# Out:
# Sales     7291.511064
# Profit    1095.221304
# dtype: float64

# %%
data_Subcategory['Sales%'] = data_Subcategory['Sales']/7.291
data_Subcategory['Profit%'] = data_Subcategory['Profit']/1.095

# %%
data_Subcategory.sort_values('Profit')
# Out:
#                     Sales      Profit      Sales%     Profit%
# Sub-Category
# Tables         648.794771  -55.565771   88.985704  -50.744997
# Bookcases      503.859633  -15.230509   69.107068  -13.909140
# Supplies       245.650200   -6.258418   33.692251   -5.715451
# Fasteners       13.936774    4.375660    1.911504    3.996036
# Art             34.068834    8.200737    4.672724    7.489258
# Furnishings     95.825668   13.645918   13.143008   12.462026
# Labels          34.303055   15.236962    4.704849   13.915033
# Binders        133.560560   19.843574   18.318552   18.121985
# Paper           57.284092   24.856620    7.856822   22.700110
# Storage        264.590553   25.152277   36.290022   22.970116
# Envelopes       64.867724   27.418019    8.896958   25.039286
# Machines      1645.553313   29.432669  225.696518   26.879149
# Appliances     230.755710   38.922758   31.649391   35.545898
# Chairs         532.332420   43.095894   73.012264   39.356980
# ...

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="Quantity")
plt.xticks(rotation=90)
plt.title("Quantity", fontsize = 5)
# Out:
# Text(0.5, 1.0, 'Quantity')

# %% [markdown]
# Quantity Wise visualize and if we see 2 and 3 quantity are the highest. It means the consumer required itmes between 2 and 3 quantity.

# %%
df_Qty = df.groupby(['Quantity']).sum()[['Profit','Sales']]
df_Qty[['Sales','Profit']].plot.pie(subplots=True, figsize=(20,10),autopct='%1.1f%%');

# %% [markdown]
# Quantity by piechart.....

# %%
fig_size = (8,4)
fig, ax = plt.subplots(figsize = fig_size)
sns.countplot(data=df, x="Discount")
plt.xticks(rotation=90)
plt.title("Discount", fontsize = 5)
# Out:
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# If we see the maximum consumer items have no discount. Maximum discount provide by store is 0.2.

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df1 = df.groupby(['State'])[['Sales','Profit','Discount']].mean()
df1
# Out:
#                             Sales      Profit  Discount
# State
# Alabama                319.846557   94.865989  0.000000
# Arizona                157.508933  -15.303235  0.303571
# Arkansas               194.635500   66.811452  0.000000
# California             228.729451   38.171608  0.072764
# Colorado               176.418231  -35.867351  0.316484
# Connecticut            163.223866   42.823071  0.007317
# Delaware               285.948635  103.930988  0.006250
# District of Columbia   286.502000  105.958930  0.000000
# Florida                233.612815   -8.875461  0.299347
# Georgia                266.825217   88.315453  0.000000
# Idaho                  208.689810   39.367767  0.085714
# Illinois               162.939230  -25.625787  0.390041
# Indiana                359.431946  123.375411  0.000000
# Iowa                   152.658667   39.460397  0.000000
# Kansas                 121.429583   34.851813  0.000000
# Kentucky               263.250000   80.573357  0.000000
# ...

# %%
data_profit = df1.sort_values('Profit')

# %%
data_sales = df1.sort_values('Sales')

# %%
data_sales['Sales'].plot(kind='bar', figsize=(15,7))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# Lowest sales: South Dakota(0.81%)
#
#
# Highest sales: Wyoming(11.84%)

# %%
data_sales['Profit'].plot(kind='bar', figsize=(15,7))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# Lowest profit: Ohio(-1.4%)
#
#
# Highest profit: Vermont(7.7%)

# %%
df1.sort_values('Profit')[['Profit','Sales']].plot(kind='bar', figsize=(18,8))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# # Evaluation

# %% [markdown]
# 1: Analysis based on segment
#
# Sales
# Lowest sales: Consumer (32.03%)
# Highest sales: Home Office (34.50%)
#
# Profit
# Lowest profit: Consumer (28.67%)
# Highest profit: Home Office (37.53%)
#
# Though there is very little differences between the classes, still, maximum and minimum can be ascertained on seeing this analysis. The corporates are on the second position for both sales and profits with Home office leading the drive in the best way for the company
#
#
#
# 2: Analysis based on State
#
# Sales
# Lowest sale: South Dakota (80.96%)
# Highest sale: Wyoming (1184.00%)
#
# The company should focus on improving their sales in South Dakota, Kansas, New Mexico, North Dakota, and few more states.
#
# Profit
# Lowest profit: Ohio (-13.66%)
# Highest profit: Vermont (77.07%)
#
# The company must ascertain reasons why 10 states are leading to a loss with Ohio leading the charts. Either the faults must be corrected or considering the present situation, if the company isn't able to come to the break-even point, the operations must be discontinued.¶
#
#
#
# 3: Analysis based on Region
#
# Sales
# Lowest sales: Central (23.40%)
# Highest sales: South (26.21%)
# The sales seem fine in all the regions since the variation range is less, however steps can still be taken to improve the sales in Central zone.
#
# Profit
# Lowest profit: Central (15.27%)
# Highest profit: West (30.25%)
# The profits have to be looked at since the West zone is giving almost double the profit as compared to the central one, so the company will have to take steps to analyze the shortcoming in terms of both sales and profits for the central region
#
#
#
# 4: Analysis of Sub Category
#
# Sales
# Lowest sales: Fasteners (1.9%)
# Highest sales: Copiers (301.59%)
#
# Profit
# Lowest profit: Tables (-50.7%)
# Highest profit: Copiers (746.9%)
# Looking at the statistical figures, the company must have the main function in copiers since the sales and profits are heavily influenced by copiers.
#
# The company must discontinue the sales of tables since it is contributing to a heavy loss and steps could be taken to improve profits for other sub categories.

# %% [markdown]
# # Thank You!
